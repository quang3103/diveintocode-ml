# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # problem 1

# %%
data = load_iris()
x = pd.DataFrame(data.data, columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
print(x)
y = pd.DataFrame(data.target, columns = ['Species'])
print(data.target_names)
print(y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
# ['setosa' 'versicolor' 'virginica']
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]

# %% [markdown]
# # problem 2

# %%
df = pd.concat([x, y], axis=1)
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# # problem 3

# %%
print("The 4th sample from the beginning:")
print(df.head(4).info())
print("Total number of samples for each label:")
print(df.Species.value_counts())
print("Check if there is a missing value in the feature quantity:")
print(df.isnull().sum())
print("Display the mean, standard deviation, and quartiles of the feature values at once")
print(df.describe())
# Out:
# The 4th sample from the beginning:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  4 non-null      float64
#  1   sepal_width   4 non-null      float64
#  2   petal_length  4 non-null      float64
#  3   petal_width   4 non-null      float64
#  4   Species       4 non-null      int32
# dtypes: float64(4), int32(1)
# memory usage: 272.0 bytes
# None
# Total number of samples for each label:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64
# Check if there is a missing value in the feature quantity:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Species         0
# dtype: int64
# Display the mean, standard deviation, and quartiles of the feature values at once
#        sepal_length  sepal_width  petal_length  petal_width     Species
# ...

# %% [markdown]
# # problem 4

# %% [markdown]
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician, eugenicist, and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".

# %% [markdown]
# # problem 5

# %% [markdown]
# The difference between .loc and .iloc is that .loc is label-based, while .iloc is integer index based (located by sequential position). Therefore, you can use .loc when you are working labels, and .iloc when you find some elements with integer index.

# %%
print("+ First Way:")
print(df['sepal_width'])
print("+ Second Way:")
print(df.iloc[:, 1])
print("+ Third Way:")
print(df.loc[:, 'sepal_width'])
print("Data from the 50th to 99th row")
print(df.iloc[50:99])
print("Data from the 50th to 99th data of the petal_length column")
print(df.iloc[50:99, 2])
print("Data with a petal_width value of 0.2")
print(df.petal_width == 0.2)
# Out:
# + First Way:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# + Second Way:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# + Third Way:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64
# Data from the 50th to 99th row
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# ...

# %% [markdown]
# # problem 6

# %%
plt.pie(df['Species'].value_counts(), labels = data.target_names, autopct='%1.1f%%')
plt.show()
fig, axes = plt.subplots(2, 2, figsize = (20, 10))
fig = sns.boxplot(ax = axes[0, 0], data = df, x = "Species", y = df.columns[0])
fig = sns.boxplot(ax = axes[0, 1], data = df, x = "Species", y = df.columns[1])
fig = sns.boxplot(ax = axes[1, 0], data = df, x = "Species", y = df.columns[2])
fig = sns.boxplot(ax = axes[1, 1], data = df, x = "Species", y = df.columns[3])

fig, axes = plt.subplots(2, 2, figsize = (20, 10))
fig = sns.violinplot(ax = axes[0, 0], data = df, x = "Species", y = df.columns[0])
fig = sns.violinplot(ax = axes[0, 1], data = df, x = "Species", y = df.columns[1])
fig = sns.violinplot(ax = axes[1, 0], data = df, x = "Species", y = df.columns[2])
fig = sns.violinplot(ax = axes[1, 1], data = df, x = "Species", y = df.columns[3])

# %% [markdown]
# # problem 7

# %%
sns.pairplot(df, hue="Species")

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width   Species
# sepal_length      1.000000    -0.117570      0.871754     0.817941  0.782561
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126 -0.426658
# petal_length      0.871754    -0.428440      1.000000     0.962865  0.949035
# petal_width       0.817941    -0.366126      0.962865     1.000000  0.956547
# Species           0.782561    -0.426658      0.949035     0.956547  1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # problem 8

# %% [markdown]
# The first thing we can see that is the number of objects is equal for 3 three species. In general, average value of all features of virginica species is quite higher than that of others. From the correlation, we can say that petal length and petal width of these these types of flower have a relation.
